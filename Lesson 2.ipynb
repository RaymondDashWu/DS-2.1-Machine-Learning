# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

np.random.seed(seed=0)

X = np.array([3.3,4.4,5.5,6.71,6.93,4.168,9.779,6.182,7.59,2.167,
                         7.042,10.791,5.313,7.997,5.654,9.27,3.1])
Y = np.array([1.7,2.76,2.09,3.19,1.694,1.573,3.366,2.596,2.53,1.221,
                         2.827,3.465,1.65,2.904,2.42,2.94,1.3])

# %%
plt.xlabel('Distance Ran')
plt.ylabel('Water (liters) Consumed')
plt.scatter(X, Y)

# %%
predicted_y = list(map(lambda x: .7 * x + .3, X))
predicted_y, type(predicted_y)
# Out:
# ([2.6099999999999994,
#   3.38,
#   4.1499999999999995,
#   4.997,
#   5.150999999999999,
#   3.2175999999999996,
#   7.1453,
#   4.6274,
#   5.6129999999999995,
#   1.8168999999999997,
#   5.229399999999999,
#   7.8537,
#   4.0191,
#   5.897899999999999,
#   4.2578,
#   6.788999999999999,
#   2.4699999999999998],
#  list)

# %%
plt.scatter(X, Y)
plt.plot(X, predicted_y)

# %%
error = sum([(i - j) **2 for i, j in zip(Y, predicted_y)])
error
# Out:
# 110.81608272999996

# %%
print(np.polyfit(X, Y, 1))
# Out:
# [0.25163494 0.79880123]

# %%
predicted_y = list(map(lambda x: .25 * x + .79, X))
plt.scatter(X, Y)
plt.plot(X, predicted_y)

# %%
error = sum([(i - j) **2 for i, j in zip(Y, predicted_y)])
error
# Out:
# 2.6219570624999986

# %%
.25*5 + .79
# Out:
# 2.04

# %%
reg.coef_.astype(float)
# Out:
# array([[0.25163494]])

# %%
plt.plot(X, reg.intercept_.astype(float))

# %%
predicted_y = list(map(lambda x: reg.coef_.astype(float) * x + reg.intercept_.astype(float), X))
plt.scatter(X, Y)
plt.plot(X, predicted_y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-a6c3702a2e1d> in <module>()
#       1 predicted_y = list(map(lambda x: reg.coef_.astype(float) * x + reg.intercept_.astype(float), X))
#       2 plt.scatter(X, Y)
# ----> 3 plt.plot(X, predicted_y)
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(*args, **kwargs)
#    3356                       mplDeprecation)
#    3357     try:
# -> 3358         ret = ax.plot(*args, **kwargs)
#    3359     finally:
#    3360         ax._hold = washold
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1853                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1854                         RuntimeWarning, stacklevel=2)
# -> 1855             return func(ax, *args, **kwargs)
#    1856
# ...

# %%
reg = LinearRegression().fit(X.reshape(-1,1), Y.reshape(-1,1))
reg.coef_, reg.intercept_
# Out:
# (array([[0.25163494]]), array([0.79880123]))

# %%
X
# Out:
# array([ 3.3  ,  4.4  ,  5.5  ,  6.71 ,  6.93 ,  4.168,  9.779,  6.182,
#         7.59 ,  2.167,  7.042, 10.791,  5.313,  7.997,  5.654,  9.27 ,
#         3.1  ])

# %%
X.reshape(-1,1)
# Out:
# array([[ 3.3  ],
#        [ 4.4  ],
#        [ 5.5  ],
#        [ 6.71 ],
#        [ 6.93 ],
#        [ 4.168],
#        [ 9.779],
#        [ 6.182],
#        [ 7.59 ],
#        [ 2.167],
#        [ 7.042],
#        [10.791],
#        [ 5.313],
#        [ 7.997],
#        [ 5.654],
#        [ 9.27 ],
#        [ 3.1  ]])

# %%
import pandas as pd

df = pd.read_csv('Advertising.csv')[:150]
df2 = pd.read_csv('Advertising.csv')

# %%
df
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# 5             6    8.7   48.9       75.0    7.2
# 6             7   57.5   32.8       23.5   11.8
# 7             8  120.2   19.6       11.6   13.2
# 8             9    8.6    2.1        1.0    4.8
# 9            10  199.8    2.6       21.2   10.6
# 10           11   66.1    5.8       24.2    8.6
# 11           12  214.7   24.0        4.0   17.4
# 12           13   23.8   35.1       65.9    9.2
# 13           14   97.5    7.6        7.2    9.7
# 14           15  204.1   32.9       46.0   19.0
# 15           16  195.4   47.7       52.9   22.4
# 16           17   67.8   36.6      114.0   12.5
# 17           18  281.4   39.6       55.8   24.4
# 18           19   69.2   20.5       18.3   11.3
# ...

# %%
X = df[['TV', 'radio', 'newspaper']]
X2 = df2[['TV', 'radio', 'newspaper']]
Y = df['sales']

# %%
reg = LinearRegression().fit(X, Y)
reg.coef_, reg.intercept_
# Out:
# (array([ 0.04700012,  0.17993257, -0.00140273]), 3.0297667962936856)

# %%
reg.predict(X2[:-50])
# Out:
# array([20.54887629, 12.12935888, 11.99986446, 17.49944016, 13.3887405 ,
#        12.13216558, 11.60109776, 12.18958782,  3.81042349, 12.85847736,
#         7.14613745, 17.43346317, 10.37156277,  8.96966628, 18.477747  ,
#        20.72216916, 12.6419954 , 23.30265766,  9.94512274, 14.22648061,
#        18.20381911, 15.07228699,  6.44152069, 16.76400286,  8.1993546 ,
#        15.98850884, 15.00043373, 17.28724677, 19.56744655,  9.16966484,
#        21.82759541, 11.4127615 ,  7.82599525, 19.11122907,  7.76920358,
#        17.41850177, 23.44813157, 15.36523981,  9.81043565, 20.48436445,
#        16.51546091, 17.30425   , 21.8106091 , 14.22849291,  8.77299852,
#        15.26378443,  8.97693237, 21.74634654, 16.48113213,  8.22766528,
#        12.92964702,  9.47088161, 20.64823258, 19.84253292, 20.53645271,
#        21.18259554,  8.37089976, 12.86260303, 21.80916442, 18.22765735,
#         5.87411983, 22.91728924, 17.02755557, 13.17090019, 16.85205749,
# ...

# %%
reg.predict([[100, 25, 25]])
# Out:
# array([12.19302467])

# %%
reg.score((reg.predict(X2[:-50])).reshape(-1, 1), (reg.predict(X[:-50])).reshape(-1, 1))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-122-1699345f79b5> in <module>()
# ----> 1 reg.score((reg.predict(X2[:-50])).reshape(-1, 1), (reg.predict(X[:-50])).reshape(-1, 1))
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/base.py in score(self, X, y, sample_weight)
#     384
#     385         from .metrics import r2_score
# --> 386         return r2_score(y, self.predict(X), sample_weight=sample_weight,
#     387                         multioutput='variance_weighted')
#     388
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/base.py in predict(self, X)
#     254             Returns predicted values.
#     255         """
# --> 256         return self._decision_function(X)
#     257
#     258     _preprocess_data = staticmethod(_preprocess_data)
#
# ...
