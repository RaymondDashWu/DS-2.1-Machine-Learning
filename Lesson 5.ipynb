# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

pima = pd.read_csv('/Users/raymondmbp/makeschool/DS-2.1-Machine-Learning/DS-2.1-Machine-Learning/Notebooks/Datasets/diabetes.csv')
feature_cols = ['Pregnancies', 'Insulin', 'BMI', 'Age']

X = pima[feature_cols]
y = pima['Outcome']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

# %%
logreg = LogisticRegression()

logreg.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
pima
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# 5              5      116             74              0        0  25.6
# 6              3       78             50             32       88  31.0
# 7             10      115              0              0        0  35.3
# 8              2      197             70             45      543  30.5
# 9              8      125             96              0        0   0.0
# 10             4      110             92              0        0  37.6
# 11            10      168             74              0        0  38.0
# ...

# %%
y_pred_prob = logreg.predict_proba(X_test)
y_pred_prob
# Out:
# array([[0.63247571, 0.36752429],
#        [0.71643656, 0.28356344],
#        [0.71104114, 0.28895886],
#        [0.5858938 , 0.4141062 ],
#        [0.84103973, 0.15896027],
#        [0.82934844, 0.17065156],
#        [0.50110974, 0.49889026],
#        [0.48658459, 0.51341541],
#        [0.72321388, 0.27678612],
#        [0.32810562, 0.67189438],
#        [0.64244443, 0.35755557],
#        [0.25912035, 0.74087965],
#        [0.63949765, 0.36050235],
#        [0.76987637, 0.23012363],
#        [0.57345769, 0.42654231],
#        [0.80896485, 0.19103515],
#        [0.54236399, 0.45763601],
#        [0.8809859 , 0.1190141 ],
#        [0.56071047, 0.43928953],
#        [0.63038849, 0.36961151],
#        [0.55812011, 0.44187989],
#        [0.62388338, 0.37611662],
#        [0.80183978, 0.19816022],
#        [0.58322696, 0.41677304],
#        [0.84451719, 0.15548281],
#        [0.7468329 , 0.2531671 ],
#        [0.90256923, 0.09743077],
#        [0.30366288, 0.69633712],
# ...

# %%
plt.hist(y_pred_prob[:, 1], bins = 8)
# Out:
# (array([ 9., 43., 46., 32., 36.,  9., 12.,  5.]),
#  array([0.02365251, 0.12078532, 0.21791813, 0.31505093, 0.41218374,
#         0.50931655, 0.60644936, 0.70358217, 0.80071498]),
#  <a list of 8 Patch objects>)

# %%
y_train.value_counts()[0], y_train.value_counts()[1], len(y_train)
# Out:
# (370, 206, 576)

# %%
threshold = y_train.value_counts()[1] / len(y_train)
threshold
# Out:
# 0.3576388888888889

# %%
from sklearn.metrics import confusion_matrix

# confusion_matrix(y_test, y_pred_prob)


for value in y_pred_prob[][1]:
    if value < threshold:
        value.append(0)
    else:
        value = 1
        
# confusion_matrix(threshold)
# Out:
#   File "<ipython-input-56-e81dc94b3ee4>", line 6
#     for value in y_pred_prob[][1]:
#                              ^
# SyntaxError: invalid syntax

# %%
y_pred_prob[0][1]
# Out:
# 0.36752429081620924

# %%
y_pred_prob
# Out:
# array([[0.63247571, 0.36752429],
#        [0.71643656, 0.28356344],
#        [0.71104114, 0.28895886],
#        [0.5858938 , 0.4141062 ],
#        [0.84103973, 0.15896027],
#        [0.82934844, 0.17065156],
#        [0.50110974, 0.49889026],
#        [0.48658459, 0.51341541],
#        [0.72321388, 0.27678612],
#        [0.32810562, 0.67189438],
#        [0.64244443, 0.35755557],
#        [0.25912035, 0.74087965],
#        [0.63949765, 0.36050235],
#        [0.76987637, 0.23012363],
#        [0.57345769, 0.42654231],
#        [0.80896485, 0.19103515],
#        [0.54236399, 0.45763601],
#        [0.8809859 , 0.1190141 ],
#        [0.56071047, 0.43928953],
#        [0.63038849, 0.36961151],
#        [0.55812011, 0.44187989],
#        [0.62388338, 0.37611662],
#        [0.80183978, 0.19816022],
#        [0.58322696, 0.41677304],
#        [0.84451719, 0.15548281],
#        [0.7468329 , 0.2531671 ],
#        [0.90256923, 0.09743077],
#        [0.30366288, 0.69633712],
# ...

# %%
def accuracy_score(tp, tn, fp, fn):
    return ((tp + tn) / float(tp + tn + fp + fn))

def precision_score(tp, fp):
    return tp / float(tp + fp)
    
def recall_score(tp, fn):
    return tp / float(fn + tp)
    
def f1_score(tp, fp, fn):
    return 2 * (precision_score(tp, fp) * recall_score(tp, fn)) / (precision_score(tp, fp) + recall_score(tp, fn))

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.hist(y, bins = 20)
plt.show()

y_pd_series = pd.Series()
